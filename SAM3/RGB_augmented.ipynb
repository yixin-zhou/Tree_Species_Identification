# %%
from PIL import Image
import numpy as np

# %%
def rgb_dsm_fusion(rgb:np.ndarray, 
                   dem:np.ndarray, 
                   dsm:np.ndarray,
                   vhm_norm = False, 
                   method="",
                   thresh=2.0):
    vhm = np.dsm - dem
    if method == "vhm_binary_mask":
